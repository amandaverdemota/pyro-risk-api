# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Avec les  feux dont le fwi est fourni dans le fichier caméra

# %%
feux = pd.read_csv("feux.csv", sep = ",")

# %%
feuxFWI = feux[feux['fwi_associe'].notna()]

# %%
surfNum = pd.to_numeric(feuxFWI["Surface parcourue (m2)"].str.replace(',',''))
plt.scatter(feuxFWI["fwi_associe"], surfNum)
plt.yscale("log")
plt.ylabel ("surface brulée en m²")
plt.xlabel("score FWI")
plt.title("surface brulé en fonction du score fwi")
plt.legend()
plt.figsize=(20,20)
plt.savefig("courbe feu_fwi.png")
# Out:
# C:\Users\Benoi\AppData\Local\Temp\ipykernel_33780\4253031338.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
feuxFWI.loc[:, "surfNum"] = surfNum
feuxFWI.loc[:, "fwi"] = pd.to_numeric(feuxFWI["fwi_associe"], errors="coerce")
# Out:
# C:\Users\Benoi\AppData\Local\Temp\ipykernel_33780\656307090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feuxFWI.loc[:, "surfNum"] = surfNum
# C:\Users\Benoi\AppData\Local\Temp\ipykernel_33780\656307090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feuxFWI.loc[:, "fwi"] = pd.to_numeric(feuxFWI["fwi_associe"], errors="coerce")

# %%
feuxFWI[feuxFWI["surfNum"] > 10000][feuxFWI["fwi"] < 20]
# Out:
# C:\Users\Benoi\AppData\Local\Temp\ipykernel_33780\1772898407.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   feuxFWI[feuxFWI["surfNum"] > 10000][feuxFWI["fwi"] < 20]
#      Unnamed: 0  Année  Numéro Département Code INSEE       Nom de la commune  \
# 29           29   2025   18561          40      40268  Saint-Laurent-de-Gosse
# 47           47   2025   14635          87      87097           Val d'Issoire
# 189         189   2025    7720          11      11369         Sallèles-d'Aude
# 207         207   2025   18574          40      40167                   Luxey
# 226         226   2025   14796          11      11262                Narbonne
# 272         272   2025    7719          11      11353   Saint-Marcel-sur-Aude
# 277         277   2025   12487          73      73249    Saint-Jeoire-Prieuré
# 299         299   2025   15970          33      33095                Captieux
# ...

# %%
plt.scatter(feuxFWI[feuxFWI["surfNum"] > 10000]["fwi_associe"], feuxFWI[feuxFWI["surfNum"] > 10000]["surfNum"])
plt.yscale("log")

# %% [markdown]
# ---

# %% [markdown]
# # Avec tout les feux de 2025, FWI récuppérés sur l'api

# %%
toutfeux = pd.read_csv("feux et fwi.csv", sep = ",")
print((toutfeux[toutfeux['fwi'].notna()]).shape == toutfeux.shape)
# Out:
# True

# %%
surfNum = pd.to_numeric(toutfeux["Surface parcourue (m2)"].str.replace(',',''))
plt.scatter(toutfeux["fwi"], surfNum)
plt.yscale("log")
plt.ylabel ("surface brulée en m²")
plt.xlabel("score FWI")
plt.title("surface brulé en fonction du score fwi")
plt.legend()
plt.figsize=(20,20)
plt.savefig("courbe étendu feu_fwi.png")
# Out:
# C:\Users\Benoi\AppData\Local\Temp\ipykernel_33780\2108874037.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Pas de corrélation entre le score fwi et l'ampleur du feu.
